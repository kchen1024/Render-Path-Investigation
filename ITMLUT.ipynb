# %% [markdown]
# <a href="https://colab.research.google.com/github/kchen1024/Render-Path-Investigation/blob/main/ITMLUT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AndreGuo/ITMLUT.git
# Out:
# Cloning into 'ITMLUT'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 213 (delta 66), reused 9 (delta 9), pack-reused 109 (from 1)
# Receiving objects: 100% (213/213), 10.27 MiB | 17.06 MiB/s, done.
# Resolving deltas: 100% (108/108), done.

# %%
# %cd ITMLUT/ailut/
# Out:
# /content/ITMLUT/ailut

# %%
# !python setup.py install
# Out:
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
# ...

# %%
# %cd ..
# Out:
# /content/ITMLUT

# %%
# !python test.py testset -out 'output' -out_format 'png'
# Out:
# /usr/local/lib/python3.12/dist-packages/ailut-1.5.0-py3.12-linux-x86_64.egg/ailut/pyinterfaces.py:15: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.12/dist-packages/ailut-1.5.0-py3.12-linux-x86_64.egg/ailut/pyinterfaces.py:36: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.12/dist-packages/ailut-1.5.0-py3.12-linux-x86_64.egg/ailut/pyinterfaces.py:53: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# ...
