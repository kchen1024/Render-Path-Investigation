# %% [markdown]
# <a href="https://colab.research.google.com/github/kchen1024/Render-Path-Investigation/blob/main/HDRTVNet_plus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/xiaom233/HDRTVNet-plus.git
# Out:
# Cloning into 'HDRTVNet-plus'...
# remote: Enumerating objects: 208, done.
# remote: Counting objects: 100% (208/208), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 208 (delta 81), reused 160 (delta 45), pack-reused 0 (from 0)
# Receiving objects: 100% (208/208), 7.27 MiB | 21.90 MiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %%
# !python HDRTVNet-plus/scripts/generate_mod_LR_bic.py
# Out:
# It will cover HDRTVNet-plus/testset/test_cond
# 1	003.
# /content/HDRTVNet-plus/scripts/generate_mod_LR_bic.py:145: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   img_pil = Image.fromarray(img_save, mode='RGB')
# 2	002.
# 3	004.
# 4	005.
# 5	001.

# %%
# %cd HDRTVNet-plus/codes/
# Out:
# /content/HDRTVNet-plus/codes

# %%
# !python test_new.py -opt options/test/test_Ensemble_AGCM_LE.yml
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 25-10-29 03:30:48.656 - INFO:   name: Ensemble_AGCM_LE_convert_test
#   model: condition
#   distortion: sr
#   scale: 1
#   gpu_ids: [0]
#   datasets:[
#     test_1:[
#       name: test_set
#       mode: LQGT_condition
#       dataroot_LQ: ../testset/test_sdr
#       dataroot_cond: ../testset/test_cond
#       dataroot_GT: ../testset/test_hdr
#       cond_scale: 4
#       testset: True
#       phase: test
#       scale: 1
#       data_type: img
#     ]
#   ]
#   network_G:[
#     which_model_G: Ensemble_AGCM_LE
#     classifier: color_condition
#     cond_c: 6
#     in_nc: 3
#     out_nc: 3
#     nf: 32
#     act_type: relu
#     weighting_network: False
#     scale: 1
#   ]
#   path:[
#     root: /content/HDRTVNet-plus/./
#     pretrain_model_G: ../pretrained_models/Ensemble_AGCM_LE.pth
#     results_root: /content/HDRTVNet-plus/./results/Ensemble_AGCM_LE_convert_test
#     log: /content/HDRTVNet-plus/./results/Ensemble_AGCM_LE_convert_test
#   ]
# ...
